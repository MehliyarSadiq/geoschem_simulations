# %%
# some default settings for plots 
# to display plots in notebook
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt # plots
import cartopy.crs as ccrs      # map projections
import pandas as pd             # large arrays
import numpy as np              # large arrays and matrices
import xarray as xr             # major tool to work with NetCDF data!

# %%
from util.functions import area_latlon
from util.gamap_colormap import WhGrYlRd

# %%
varname = 'SpeciesConc_CO2Tag15'
ilevel = 0
# load data
fname = '/home/msadiq/Desktop/co2/data/outputs/SpeciesConc.201801.nc'
ds = xr.open_dataset(fname)
#ds

# %%
# read in one month of data, [180,360]
dr = ds[varname]
dr_monthly_1=dr.mean(dim='record')
dr_1 = dr_monthly_1[0,ilevel,:,:]*1e6

# %%
# global map
fig = plt.figure(figsize=[8, 4])
proj=ccrs.PlateCarree()

ax = plt.subplot(111, projection=proj)

dr_1.plot(ax=ax, transform=ccrs.PlateCarree(), cmap=WhGrYlRd, cbar_kwargs={'shrink': 0.8})

ax.coastlines();

# %%
# load data
fname = '/home/msadiq/Desktop/co2/data/outputs/SpeciesConc.201803.nc'
ds = xr.open_dataset(fname)
#ds

# %%
# read in one month of data, [180,360]
dr = ds[varname]
dr_monthly_2=dr.mean(dim='record')
dr_2 = dr_monthly_2[0,ilevel,:,:]*1e6

# %%
# global map
fig = plt.figure(figsize=[8, 4])
proj=ccrs.PlateCarree()

ax = plt.subplot(111, projection=proj)

dr_2.plot(ax=ax, transform=ccrs.PlateCarree(), cmap=WhGrYlRd, cbar_kwargs={'shrink': 0.8})

ax.coastlines();

# %%
diff = dr_2 - dr_1
# global map
fig = plt.figure(figsize=[8, 4])
proj=ccrs.PlateCarree()

ax = plt.subplot(111, projection=proj)

diff.plot(ax=ax, transform=ccrs.PlateCarree(), cbar_kwargs={'shrink': 0.8})

ax.coastlines();
