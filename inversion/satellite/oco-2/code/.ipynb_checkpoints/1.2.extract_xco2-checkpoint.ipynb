# %% [markdown]
# # Explore XCO2 in OCO-2 dataset

# %%
# to display plots in notebook
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

from matplotlib import rcParams
rcParams["savefig.dpi"] = 300  # high res plots
rcParams["font.size"] = 8

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import packages

# %%
import matplotlib.pyplot as plt # plots
import cartopy.crs as ccrs      # map projections
import pandas as pd             # large arrays
import numpy as np              # large arrays and matrices
import xarray as xr             # major tool to work with NetCDF data!
# custom color map downloaded from GEOS-Chem python tutorial
from gamap_colormap import WhGrYlRd  # import the "WhGrYlRd" variable
#type(WhGrYlRd)
import re

# %% [markdown]
# ### Read in OCO-2 file

# %%
fname = '/home/msadiq/Desktop/co2/data/satellite/OCO2_b91_10sec_GOOD_r24.nc4'
ds = xr.open_dataset(fname, engine='netcdf4')
#ds # same as print(ds)

# %% [markdown]
# ### Read in data and use Pandas package

# %%
# first and last day of extraction
first_day = '2018-03-01'
last_day_p1 = '2018-03-03' # last day plus 1

# %%
dr_xco2 = ds['xco2']                     # column co2 concentration, ppm
dr_kernel = ds['xco2_averaging_kernel']  # averaging kernel to get xco2 from [co2]
lon_series = ds['longitude']
lat_series = ds['latitude']
sound_id = ds['sounding_id']             # time

# convert time input to match the format of sound_id
first_day_digital = re.sub("[^0-9]", "", first_day)
last_day_p1_digital = re.sub("[^0-9]", "", last_day_p1)
begin = int(first_day_digital + '000000')  # begin and end of time slice we want to look at
end = int(last_day_p1_digital + '000000')  # OCO-2 format

# %%
# following 4 lines could prob be simplified, combine them first, and then slice???
# get a slice of time window
slice_xco2 = dr_xco2.sel(sounding_id=slice(begin, end))
slice_lon = lon_series.sel(sounding_id=slice(begin, end))
slice_lat = lat_series.sel(sounding_id=slice(begin, end))
sound_id = sound_id.sel(sounding_id=slice(begin, end))
df_xco2 = pd.DataFrame({'sound_id': sound_id, 'lon': slice_lon, 'lat': slice_lat, 'xco2': slice_xco2})
#df_xco2.head()
df_xco2.head()
# Out:
#          sound_id         lon        lat        xco2
# 0  20180301005336 -166.029999 -33.000000  404.010010
# 1  20180301005346 -166.080002 -32.779999  404.410004
# 2  20180301005416 -166.570007 -30.740000  404.170013
# 3  20180301005436 -166.789993 -29.809999  403.880005
# 4  20180301005446 -166.919998 -29.320000  404.190002

# %%
# Creat target grid
lat_res = 2 # horizontal resolution of lat and lon you would want
lon_res = 2.5
lat = np.linspace(-90, 90, 180/lat_res+1) # grid
lon = np.linspace(-180, 177.5, 360/lon_res)

day_1 = np.array(first_day,dtype='datetime64[D]')
day_end = np.array(last_day_p1,dtype='datetime64[D]')
days = np.arange(day_1, day_end, dtype='datetime64[D]') # time dimension of output

xco2 = xr.DataArray(data = 0, 
                      dims = ('lat', 'lon', 'time'), 
                      coords = {'lat': lat,
                              'lon': lon,
                              'time': days},
                      name = 'XCO2')

xco2 = xco2.astype(dtype='float32')
#xco2

# %%
print(type(last_day_p1_digital))
days_range = np.arange(int(first_day_digital),int(last_day_p1_digital))
days_range
# Out:
# <class 'str'>
# array([20180301, 20180302])

# %%
# map XCO2 to target grid
for c, iday in enumerate(days_range):
    for ilon in np.arange(len(lon)-1):
        for ilat in np.arange(len(lat)-1):
            begin = int(str(iday) + '000000')  # begin and end of time slice we want to look at
            end = int(str(iday+1) + '000000')  # OCO-2 format
            df_time_slice = df_xco2[df_xco2['sound_id'].between(begin, end)]
            df_slice_lat = df_time_slice[df_xco2['lat'].between(lat[ilat],lat[ilat+1], inclusive = True)]
            df_slice_lon = df_slice_lat[df_slice_lat['lon'].between(lon[ilon],lon[ilon+1], inclusive = True)]
            if len(df_slice_lon.xco2) != 0:
                print(begin)
                print(len(df_slice_lon.xco2))
                xco2[ilat,ilon,c] = df_slice_lon.xco2.mean() # include deviation as well?
# Out:
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 4
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 4
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 2
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 3
# 20180301000000
# 4
# 20180301000000
# 3
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 1
# 20180301000000
# 2
# 20180301000000
# 4
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 6
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 5
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 1
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 3
# 20180302000000
# 1
# 20180302000000
# 3
# 20180302000000
# 3
# 20180302000000
# 4
# 20180302000000
# 4
# 20180302000000
# 2
# 20180302000000
# 2
# 20180302000000
# 1
# 20180302000000
# 3

# %%
# plot after mapping
fig = plt.figure(figsize=[6, 6])
proj=ccrs.PlateCarree()

ax = plt.subplot(111, projection=proj)
ax.coastlines()
xco2.isel(time=0).plot(ax=ax, transform=ccrs.PlateCarree(), vmax=412, vmin=398, cmap=WhGrYlRd, cbar_kwargs={'shrink': 0.4, 'label': 'ppm'})

ax.set_title('OCO-2: XCO2');
