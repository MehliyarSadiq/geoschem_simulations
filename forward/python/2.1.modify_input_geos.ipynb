# %%
f = open('input.geos', 'r+')
#f.close()

# %%
for line in f:
    print(line, end='')
f.close()
# Out:
# ------------------------+------------------------------------------------------
# %%% SIMULATION MENU %%% :
# Start YYYYMMDD, hhmmss  : 20180101 000000
# End   YYYYMMDD, hhmmss  : 20180901 000000
# Run directory           : ./
# Root data directory     : /geos/d21/GC_DATA/
# Met field               : geosfp
# Simulation name         : CO2
# ------------------------+------------------------------------------------------
# %%% GRID MENU %%%       :
# Grid resolution         : 2.0x2.5
# Longitude min/max       : -180.0 180.0
# Latitude  min/max       :  -90.0  90.0
#  Half-sized polar boxes?: T
# Number of levels        : 47
# Nested grid simulation? : F
#  Buffer zone (N S E W ) :  0  0  0  0
# ------------------------+------------------------------------------------------
# %%% TIMESTEP MENU %%%   :
# Tran/conv timestep [sec]: 600
# Chem/emis timestep [sec]: 1200
# ------------------------+------------------------------------------------------
# %%% ADVECTED SPECIES MENU %%%:
# ...
