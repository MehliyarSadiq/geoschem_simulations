# %%
# check 2016 and 2017 outputs
# %run tools.ipynb

# %%
mod_dir = '/scratch/local/msadiq/rundir/2017/CO2-TC67-2017-12/nd51/'

fname = mod_dir + '2d_ts_satellite.201802.nc'

ftmp = xr.open_dataset(fname)
ftmp
#print(ftmp)

#dr_tmp  = ftmp['SpeciesConc_CO2Tag3'][0,0,:,:] # ppbv
#dr_tmp1 = ftmp['SpeciesConc_CO2Tag11'][0,0,:,:]
#diff = dr_tmp - dr_tmp1

dr_tmp  = ftmp['SpeciesConc_CO2Tag3'][:,0] # ppbv
dr_tmp1 = ftmp['SpeciesConc_CO2Tag11'][:,0]
diff = dr_tmp - dr_tmp1
plt.plot(diff)
#plt.plot(dr_tmp[9000:12000])
#diff = (dr_tmp[29,0,:,:]*1e-3 - 100)
#diff.plot()

#dr_tmp1 = ftmp['X_SpeciesConc_CO2Tag11']

# %%
mod_dir = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/2017/CO2-TC67-2017-06/nd51/'

fname = mod_dir + '2d_ts_satellite.201708.nc'

ftmp = xr.open_dataset(fname)
ftmp
#print(ftmp)

#dr_tmp  = ftmp['SpeciesConc_CO2Tag3'][0,0,:,:] # ppbv
#dr_tmp1 = ftmp['SpeciesConc_CO2Tag11'][0,0,:,:]
#diff = dr_tmp - dr_tmp1

dr_tmp  = ftmp['SpeciesConc_CO2Tag3'][:,0] # ppbv
dr_tmp1 = ftmp['SpeciesConc_CO2Tag11'][:,0]
diff = dr_tmp - dr_tmp1
plt.plot(diff)
#plt.plot(dr_tmp[9000:12000])
#diff = (dr_tmp[29,0,:,:]*1e-3 - 100)
diff.plot()

#dr_tmp1 = ftmp['X_SpeciesConc_CO2Tag11']

# %%
mod_dir = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/2016/CO2-TC67-2016-01/nd51/'

fname = mod_dir + 'delta_y0_model_N_1.nc'

ftmp = xr.open_dataset(fname)
#ftmp
#print(ftmp)

dr_tmp  = ftmp['X_SpeciesConc_CO2Tag3'] # ppbv
dr_tmp1 = ftmp['X_SpeciesConc_CO2Tag11']
diff = dr_tmp - dr_tmp1

#plt.plot(ftmp['X_SpeciesConc_CO2Tag63'])
#diff = (dr_tmp[29,0,:,:]*1e-3 - 100)
diff.plot()

#dr_tmp1 = ftmp['X_SpeciesConc_CO2Tag11']

# %%
mod_dir = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/2016/CO2-TC67-2016-04/nd51/'

fname = mod_dir + '2d_ts_satellite.201604.nc'

ftmp = xr.open_dataset(fname)
#print(ftmp)

dr_tmp  = ftmp['SpeciesConc_CO2Tag3'][:,0] # ppbv
dr_tmp1 = ftmp['SpeciesConc_CO2Tag11'][:,0]
diff = dr_tmp - dr_tmp1

plt.plot(diff)
#diff = (dr_tmp[29,0,:,:]*1e-3 - 100)
#diff.plot()

#dr_tmp1 = ftmp['X_SpeciesConc_CO2Tag11']

# %%
mod_dir = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/2016/CO2-TC67-2016-04/nd51/'

fname = mod_dir + 'ts_satellite.201604.nc'

ftmp = xr.open_dataset(fname)
#print(ftmp)

dr_tmp  = ftmp['SpeciesConc_CO2Tag6'] # ppbv
#print(dr_tmp)
diff = (dr_tmp[29,0,:,:]*1e-3 - 100)
diff.plot()

#dr_tmp1 = ftmp['X_SpeciesConc_CO2Tag11']
# Out:
# <xarray.DataArray 'SpeciesConc_CO2Tag6' (time: 30, lev: 47, lat: 91, lon: 144)>
# [18476640 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 2016-04-01 2016-04-02 ... 2016-04-30
#   * lev      (lev) float64 0.9925 0.9775 0.9624 ... 0.0003988 0.000127 2.763e-05
#   * lat      (lat) float64 -89.5 -88.0 -86.0 -84.0 -82.0 ... 84.0 86.0 88.0 89.5
#   * lon      (lon) float64 -180.0 -177.5 -175.0 -172.5 ... 172.5 175.0 177.5
# Attributes:
#     units:      ppbv
#     long_name:  CO2Tag6 tracer

# %%
mod_dir = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/2018/CO2-TC67-2018-01/OutputDir/'

fname = mod_dir + 'GEOSChem.SpeciesConc.20180101_0000z.nc4'

ftmp = xr.open_dataset(fname)
ftmp

dr_tmp  = ftmp['SpeciesConc_CO2Tag63']# - ftmp['SpeciesConc_CO2Tag13']
diff = dr_tmp[0,0,:,:]*1e6 - 100
diff.plot()
#dr_tmp1 = ftmp['X_SpeciesConc_CO2Tag11']

# %%
mod_dir = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/2016/CO2-TC67-2016-01/OutputDir/'

fname = mod_dir + 'GEOSChem.SpeciesConc.20160101_0000z.nc4'

ftmp = xr.open_dataset(fname)
ftmp

dr_tmp  = ftmp['SpeciesConc_CO2Tag5']# - ftmp['SpeciesConc_CO2Tag13']
diff = dr_tmp[0,0,:,:]*1e6 - 100
diff.plot()
#dr_tmp1 = ftmp['X_SpeciesConc_CO2Tag6']

# %%
mod_dir = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/2016/CO2-TC67-2016-08/nd51/'

fname = mod_dir + 'delta_y0_model_N_8.nc'

ftmp = xr.open_dataset(fname)
dr_tmp  = ftmp['X_SpeciesConc_CO2Tag3']
dr_tmp1 = ftmp['X_SpeciesConc_CO2Tag11']

# %%
for i in range(1,68):
    dr_tmp = ftmp['X_SpeciesConc_CO2Tag' + str(i)]
    plt.plot(dr_tmp)

# %%
diff = dr_tmp - dr_tmp1
diff.plot()

# %%
mod_dir = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/2016/CO2-TC67-2016-02/nd51/'

fname = mod_dir + 'interpolated_2d_ts_satellite.201602.nc'

ftmp = xr.open_dataset(fname)
dr_tmp  = ftmp['SpeciesConc_CO2Tag3']
dr_tmp1 = ftmp['SpeciesConc_CO2Tag11']

# %%
diff = dr_tmp - dr_tmp1
diff.plot()

# %%
dr_tmp[0:10000].plot()
