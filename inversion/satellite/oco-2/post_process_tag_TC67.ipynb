# %%
# %run ./tools.ipynb
# import all the necessary modules 
# import all functions needed to post process

# %%
# %%time
### this cell could do all post-processing for a case, over a few months, or one month

year = 2017
tag_month = 12 # month of flux tagged
iyear = 2017
imonth = 12

case_name = 'CO2-TC67-' + str(year) + '-' + month_string(tag_month)
mod_dir = '/scratch/local/msadiq/rundir/' + str(year) + '/' + case_name + '/nd51/'

## convert bpch files to netcdf
bpch_to_nc_mass(data_dir = mod_dir,
                            year = iyear,
                            month = imonth)
    # combine daily outputs into monthly
combine_daily_to_one(data_dir = mod_dir,
                                 year = iyear,
                                 month = imonth,
                                 str1 = 'ts_satellite.',
                                 str2 = '.nc')
flatten_4d_to_2d(data_dir = mod_dir,
                                 year = iyear,
                                 month = imonth,
                                 str1 = 'ts_satellite.',
                                 str2 = '.nc')  
# interpolate to satellite grid
interpolate_model_to_satellite2(mod_dir = mod_dir, 
                                               sat_dir = '/geos/u73/msadiq/satellite/oco-2/', 
                                               year = iyear, 
                                               month = imonth, 
                                               str1_mod = '2d_ts_satellite.', 
                                               str1_sat = '2d_OCO2_extract_',
                                               background = 100)
# calculate XCO2 difference
delta_Y(mod_dir = mod_dir, 
                    sat_dir = '/geos/u73/msadiq/satellite/oco-2/', 
                    year = iyear, 
                    month = imonth, 
                    str1_mod = 'interpolated_2d_ts_satellite.', 
                    str1_sat = '2d_OCO2_extract_',
                    mode = 'N')
# Out:
# converted daily bpch outputs to netcdf format
# created ts_satellite.201712.nc
# created 2d_ts_satellite.201712.nc
# interpolation began
# SpeciesConc_CO2Tag1 done
# SpeciesConc_CO2Tag2 done
# SpeciesConc_CO2Tag3 done
# SpeciesConc_CO2Tag4 done
# SpeciesConc_CO2Tag5 done
# SpeciesConc_CO2Tag6 done
# SpeciesConc_CO2Tag7 done
# SpeciesConc_CO2Tag8 done
# SpeciesConc_CO2Tag9 done
# SpeciesConc_CO2Tag10 done
# SpeciesConc_CO2Tag11 done
# SpeciesConc_CO2Tag12 done
# SpeciesConc_CO2Tag13 done
# SpeciesConc_CO2Tag14 done
# SpeciesConc_CO2Tag15 done
# SpeciesConc_CO2Tag16 done
# SpeciesConc_CO2Tag17 done
# SpeciesConc_CO2Tag18 done
# SpeciesConc_CO2Tag19 done
# SpeciesConc_CO2Tag20 done
# SpeciesConc_CO2Tag21 done
# SpeciesConc_CO2Tag22 done
# SpeciesConc_CO2Tag23 done
# SpeciesConc_CO2Tag24 done
# SpeciesConc_CO2Tag25 done
# SpeciesConc_CO2Tag26 done
# SpeciesConc_CO2Tag27 done
# SpeciesConc_CO2Tag28 done
# SpeciesConc_CO2Tag29 done
# SpeciesConc_CO2Tag30 done
# SpeciesConc_CO2Tag31 done
# SpeciesConc_CO2Tag32 done
# SpeciesConc_CO2Tag33 done
# SpeciesConc_CO2Tag34 done
# SpeciesConc_CO2Tag35 done
# SpeciesConc_CO2Tag36 done
# SpeciesConc_CO2Tag37 done
# SpeciesConc_CO2Tag38 done
# SpeciesConc_CO2Tag39 done
# SpeciesConc_CO2Tag40 done
# SpeciesConc_CO2Tag41 done
# SpeciesConc_CO2Tag42 done
# SpeciesConc_CO2Tag43 done
# SpeciesConc_CO2Tag44 done
# SpeciesConc_CO2Tag45 done
# SpeciesConc_CO2Tag46 done
# SpeciesConc_CO2Tag47 done
# SpeciesConc_CO2Tag48 done
# SpeciesConc_CO2Tag49 done
# SpeciesConc_CO2Tag50 done
# SpeciesConc_CO2Tag51 done
# SpeciesConc_CO2Tag52 done
# SpeciesConc_CO2Tag53 done
# SpeciesConc_CO2Tag54 done
# SpeciesConc_CO2Tag55 done
# SpeciesConc_CO2Tag56 done
# SpeciesConc_CO2Tag57 done
# SpeciesConc_CO2Tag58 done
# SpeciesConc_CO2Tag59 done
# SpeciesConc_CO2Tag60 done
# SpeciesConc_CO2Tag61 done
# SpeciesConc_CO2Tag62 done
# SpeciesConc_CO2Tag63 done
# SpeciesConc_CO2Tag64 done
# SpeciesConc_CO2Tag65 done
# SpeciesConc_CO2Tag66 done
# SpeciesConc_CO2Tag67 done
# created interpolated_2d_ts_satellite.201712.nc
# created delta_y0_model_N_12.nc
# CPU times: user 29min 24s, sys: 1min 5s, total: 30min 29s
# Wall time: 30min 19s

# %%
# %%time
### this cell could do all post-processing for a case, over a few months, or one month

year = 2018
tag_month = 8 # month of flux tagged
lag_window = 2 #
case_name = 'CO2-TC67-2018-' + month_string(tag_month)
mod_dir = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/' + case_name + '/nd51/'

for imonth in range(tag_month,tag_month + lag_window): # months of tagged runs

    # convert bpch files to netcdf
    bpch_to_nc_mass(data_dir = mod_dir,
                            year = year,
                            month = imonth)
    # combine daily outputs into monthly
    combine_daily_to_one(data_dir = mod_dir,
                                 year = year,
                                 month = imonth,
                                 str1 = 'ts_satellite.',
                                 str2 = '.nc')
    # flatten 4d to 2d array
    flatten_4d_to_2d(data_dir = mod_dir,
                                 year = year,
                                 month = imonth,
                                 str1 = 'ts_satellite.',
                                 str2 = '.nc')

    # interpolate to satellite grid
    interpolate_model_to_satellite2(mod_dir = mod_dir, 
                                               sat_dir = '/geos/u73/msadiq/satellite/oco-2/', 
                                               year = year, 
                                               month = imonth, 
                                               str1_mod = '2d_ts_satellite.', 
                                               str1_sat = '2d_OCO2_extract_',
                                               background = 100)
    # calculate XCO2 difference
    delta_Y(mod_dir = mod_dir, 
                    sat_dir = '/geos/u73/msadiq/satellite/oco-2/', 
                    year = year, 
                    month = imonth, 
                    str1_mod = 'interpolated_2d_ts_satellite.', 
                    str1_sat = '2d_OCO2_extract_',
                    mode = 'N')
# Out:
# converted daily bpch outputs to netcdf format
# created ts_satellite.201808.nc
# created 2d_ts_satellite.201808.nc
# interpolation began
# SpeciesConc_CO2Tag1 done
# SpeciesConc_CO2Tag2 done
# SpeciesConc_CO2Tag3 done
# SpeciesConc_CO2Tag4 done
# SpeciesConc_CO2Tag5 done
# SpeciesConc_CO2Tag6 done
# SpeciesConc_CO2Tag7 done
# SpeciesConc_CO2Tag8 done
# SpeciesConc_CO2Tag9 done
# SpeciesConc_CO2Tag10 done
# SpeciesConc_CO2Tag11 done
# SpeciesConc_CO2Tag12 done
# SpeciesConc_CO2Tag13 done
# SpeciesConc_CO2Tag14 done
# SpeciesConc_CO2Tag15 done
# SpeciesConc_CO2Tag16 done
# SpeciesConc_CO2Tag17 done
# SpeciesConc_CO2Tag18 done
# SpeciesConc_CO2Tag19 done
# SpeciesConc_CO2Tag20 done
# SpeciesConc_CO2Tag21 done
# SpeciesConc_CO2Tag22 done
# SpeciesConc_CO2Tag23 done
# SpeciesConc_CO2Tag24 done
# SpeciesConc_CO2Tag25 done
# SpeciesConc_CO2Tag26 done
# SpeciesConc_CO2Tag27 done
# SpeciesConc_CO2Tag28 done
# SpeciesConc_CO2Tag29 done
# SpeciesConc_CO2Tag30 done
# SpeciesConc_CO2Tag31 done
# SpeciesConc_CO2Tag32 done
# SpeciesConc_CO2Tag33 done
# SpeciesConc_CO2Tag34 done
# SpeciesConc_CO2Tag35 done
# SpeciesConc_CO2Tag36 done
# SpeciesConc_CO2Tag37 done
# SpeciesConc_CO2Tag38 done
# SpeciesConc_CO2Tag39 done
# SpeciesConc_CO2Tag40 done
# SpeciesConc_CO2Tag41 done
# SpeciesConc_CO2Tag42 done
# SpeciesConc_CO2Tag43 done
# SpeciesConc_CO2Tag44 done
# SpeciesConc_CO2Tag45 done
# SpeciesConc_CO2Tag46 done
# SpeciesConc_CO2Tag47 done
# SpeciesConc_CO2Tag48 done
# SpeciesConc_CO2Tag49 done
# SpeciesConc_CO2Tag50 done
# SpeciesConc_CO2Tag51 done
# SpeciesConc_CO2Tag52 done
# SpeciesConc_CO2Tag53 done
# SpeciesConc_CO2Tag54 done
# SpeciesConc_CO2Tag55 done
# SpeciesConc_CO2Tag56 done
# SpeciesConc_CO2Tag57 done
# SpeciesConc_CO2Tag58 done
# SpeciesConc_CO2Tag59 done
# SpeciesConc_CO2Tag60 done
# SpeciesConc_CO2Tag61 done
# SpeciesConc_CO2Tag62 done
# SpeciesConc_CO2Tag63 done
# SpeciesConc_CO2Tag64 done
# SpeciesConc_CO2Tag65 done
# SpeciesConc_CO2Tag66 done
# SpeciesConc_CO2Tag67 done
# created interpolated_2d_ts_satellite.201808.nc
# created delta_y0_model_N_8.nc
# converted daily bpch outputs to netcdf format
# created ts_satellite.201809.nc
# created 2d_ts_satellite.201809.nc
# interpolation began
# SpeciesConc_CO2Tag1 done
# SpeciesConc_CO2Tag2 done
# SpeciesConc_CO2Tag3 done
# SpeciesConc_CO2Tag4 done
# SpeciesConc_CO2Tag5 done
# SpeciesConc_CO2Tag6 done
# SpeciesConc_CO2Tag7 done
# SpeciesConc_CO2Tag8 done
# SpeciesConc_CO2Tag9 done
# SpeciesConc_CO2Tag10 done
# SpeciesConc_CO2Tag11 done
# SpeciesConc_CO2Tag12 done
# SpeciesConc_CO2Tag13 done
# SpeciesConc_CO2Tag14 done
# SpeciesConc_CO2Tag15 done
# SpeciesConc_CO2Tag16 done
# SpeciesConc_CO2Tag17 done
# SpeciesConc_CO2Tag18 done
# SpeciesConc_CO2Tag19 done
# SpeciesConc_CO2Tag20 done
# SpeciesConc_CO2Tag21 done
# SpeciesConc_CO2Tag22 done
# SpeciesConc_CO2Tag23 done
# SpeciesConc_CO2Tag24 done
# SpeciesConc_CO2Tag25 done
# SpeciesConc_CO2Tag26 done
# SpeciesConc_CO2Tag27 done
# SpeciesConc_CO2Tag28 done
# SpeciesConc_CO2Tag29 done
# SpeciesConc_CO2Tag30 done
# SpeciesConc_CO2Tag31 done
# SpeciesConc_CO2Tag32 done
# SpeciesConc_CO2Tag33 done
# SpeciesConc_CO2Tag34 done
# SpeciesConc_CO2Tag35 done
# SpeciesConc_CO2Tag36 done
# SpeciesConc_CO2Tag37 done
# SpeciesConc_CO2Tag38 done
# SpeciesConc_CO2Tag39 done
# SpeciesConc_CO2Tag40 done
# SpeciesConc_CO2Tag41 done
# SpeciesConc_CO2Tag42 done
# SpeciesConc_CO2Tag43 done
# SpeciesConc_CO2Tag44 done
# SpeciesConc_CO2Tag45 done
# SpeciesConc_CO2Tag46 done
# SpeciesConc_CO2Tag47 done
# SpeciesConc_CO2Tag48 done
# SpeciesConc_CO2Tag49 done
# SpeciesConc_CO2Tag50 done
# SpeciesConc_CO2Tag51 done
# SpeciesConc_CO2Tag52 done
# SpeciesConc_CO2Tag53 done
# SpeciesConc_CO2Tag54 done
# SpeciesConc_CO2Tag55 done
# SpeciesConc_CO2Tag56 done
# SpeciesConc_CO2Tag57 done
# SpeciesConc_CO2Tag58 done
# SpeciesConc_CO2Tag59 done
# SpeciesConc_CO2Tag60 done
# SpeciesConc_CO2Tag61 done
# SpeciesConc_CO2Tag62 done
# SpeciesConc_CO2Tag63 done
# SpeciesConc_CO2Tag64 done
# SpeciesConc_CO2Tag65 done
# SpeciesConc_CO2Tag66 done
# SpeciesConc_CO2Tag67 done
# created interpolated_2d_ts_satellite.201809.nc
# created delta_y0_model_N_9.nc

# %%
year = 2018
tag_month = 8 # month of flux tagged
#lag_window = 2 #
case_name = 'CO2-TC67-2018-' + month_string(tag_month)
mod_dir = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/' + case_name + '/nd51/'

imonth = 10
# convert bpch files to netcdf
bpch_to_nc_mass(data_dir = mod_dir,
                            year = year,
                            month = imonth)
    # combine daily outputs into monthly
combine_daily_to_one(data_dir = mod_dir,
                                 year = year,
                                 month = imonth,
                                 str1 = 'ts_satellite.',
                                 str2 = '.nc')
    # flatten 4d to 2d array
flatten_4d_to_2d(data_dir = mod_dir,
                                 year = year,
                                 month = imonth,
                                 str1 = 'ts_satellite.',
                                 str2 = '.nc')

    # interpolate to satellite grid
interpolate_model_to_satellite2(mod_dir = mod_dir, 
                                               sat_dir = '/geos/u73/msadiq/satellite/oco-2/', 
                                               year = year, 
                                               month = imonth, 
                                               str1_mod = '2d_ts_satellite.', 
                                               str1_sat = '2d_OCO2_extract_',
                                               background = 100)
    # calculate XCO2 difference
delta_Y(mod_dir = mod_dir, 
                    sat_dir = '/geos/u73/msadiq/satellite/oco-2/', 
                    year = year, 
                    month = imonth, 
                    str1_mod = 'interpolated_2d_ts_satellite.', 
                    str1_sat = '2d_OCO2_extract_',
                    mode = 'N')
# Out:
# converted daily bpch outputs to netcdf format
# created ts_satellite.201810.nc
# created 2d_ts_satellite.201810.nc
# interpolation began
# SpeciesConc_CO2Tag1 done
# SpeciesConc_CO2Tag2 done
# SpeciesConc_CO2Tag3 done
# SpeciesConc_CO2Tag4 done
# SpeciesConc_CO2Tag5 done
# SpeciesConc_CO2Tag6 done
# SpeciesConc_CO2Tag7 done
# SpeciesConc_CO2Tag8 done
# SpeciesConc_CO2Tag9 done
# SpeciesConc_CO2Tag10 done
# SpeciesConc_CO2Tag11 done
# SpeciesConc_CO2Tag12 done
# SpeciesConc_CO2Tag13 done
# SpeciesConc_CO2Tag14 done
# SpeciesConc_CO2Tag15 done
# SpeciesConc_CO2Tag16 done
# SpeciesConc_CO2Tag17 done
# SpeciesConc_CO2Tag18 done
# SpeciesConc_CO2Tag19 done
# SpeciesConc_CO2Tag20 done
# SpeciesConc_CO2Tag21 done
# SpeciesConc_CO2Tag22 done
# SpeciesConc_CO2Tag23 done
# SpeciesConc_CO2Tag24 done
# SpeciesConc_CO2Tag25 done
# SpeciesConc_CO2Tag26 done
# SpeciesConc_CO2Tag27 done
# SpeciesConc_CO2Tag28 done
# SpeciesConc_CO2Tag29 done
# SpeciesConc_CO2Tag30 done
# SpeciesConc_CO2Tag31 done
# SpeciesConc_CO2Tag32 done
# SpeciesConc_CO2Tag33 done
# SpeciesConc_CO2Tag34 done
# SpeciesConc_CO2Tag35 done
# SpeciesConc_CO2Tag36 done
# SpeciesConc_CO2Tag37 done
# SpeciesConc_CO2Tag38 done
# SpeciesConc_CO2Tag39 done
# SpeciesConc_CO2Tag40 done
# SpeciesConc_CO2Tag41 done
# SpeciesConc_CO2Tag42 done
# SpeciesConc_CO2Tag43 done
# SpeciesConc_CO2Tag44 done
# SpeciesConc_CO2Tag45 done
# SpeciesConc_CO2Tag46 done
# SpeciesConc_CO2Tag47 done
# SpeciesConc_CO2Tag48 done
# SpeciesConc_CO2Tag49 done
# SpeciesConc_CO2Tag50 done
# SpeciesConc_CO2Tag51 done
# SpeciesConc_CO2Tag52 done
# SpeciesConc_CO2Tag53 done
# SpeciesConc_CO2Tag54 done
# SpeciesConc_CO2Tag55 done
# SpeciesConc_CO2Tag56 done
# SpeciesConc_CO2Tag57 done
# SpeciesConc_CO2Tag58 done
# SpeciesConc_CO2Tag59 done
# SpeciesConc_CO2Tag60 done
# SpeciesConc_CO2Tag61 done
# SpeciesConc_CO2Tag62 done
# SpeciesConc_CO2Tag63 done
# SpeciesConc_CO2Tag64 done
# SpeciesConc_CO2Tag65 done
# SpeciesConc_CO2Tag66 done
# SpeciesConc_CO2Tag67 done
# created interpolated_2d_ts_satellite.201810.nc
# created delta_y0_model_N_10.nc

# %%
ts_files = mod_dir + 'ts_satellite.' + str(year) + month_string(imonth) + '*'
# !ls {ts_files}
#!rm -rf {ts_files}
# Out:
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180401.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180401.nc
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180402.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180403.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180404.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180405.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180406.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180407.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180408.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180409.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180410.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180411.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180412.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180413.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180414.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180415.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180416.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180417.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180418.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180419.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180420.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180421.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180422.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180423.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180424.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180425.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180426.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180427.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180428.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180429.bpch
# /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-TC67-2018-04/nd51/ts_satellite.20180430.bpch

# %%
year = 2018
assim_month = 3
top_dir = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/'
mod_dir = top_dir + 'CO2-' + str(year) + '/nd51/'
# 1, read in from full CO2 simulations
name_month = short_name_of_month(assim_month) # Jan, Feb, Mar, ...
xco2_file = 'XCO2_mod_and_oco2_N_' + name_month + '.nc'
ds_xco2 = xr.open_dataset(mod_dir + xco2_file)
xco2_oco2  = ds_xco2['xco2_oco2']  # XCO2 from OCO-2
xco2_model = ds_xco2['xco2_model'] # XCO2 from model
xco2_error = ds_xco2['xco2_error'] # measurement error from OCO-2
diff = ds_xco2['xco2_oco2'] - ds_xco2['xco2_model']
# reduce the size of above arrays and matrices, from ~400k to <3k
x = xco2_oco2.copy()
x = x[np.logical_not(np.isnan(x))]
ind = x.record.values   # index for slicing

for i in range(3):
    mod_dir = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-casa-2018-0' + str(i+1) + '/nd51/'
    fname = 'delta_y0_model_N_3.nc'
    ds = xr.open_dataset(mod_dir + fname)
    tmp = ds['X_SpeciesConc_CO2Tag10'][ind].values
    plt.plot(tmp[10:150], label = short_name_of_month(i+1))
plt.legend()

# %%
# Convert one bpch file and check
case_name = 'CO2-bio-2018-07'
directory = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/' + case_name + '/'
name_bpch = 'ts_satellite.20180708.bpch'
bpchfile = directory + name_bpch
tinfo_file = directory + 'tracerinfo.dat'
dinfo_file = directory + 'diaginfo.dat'
# Output
output_directory = '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/' + case_name + '/'
ncfile = output_directory + 'ts_satellite.20180708.nc'

bpch_2_netcdf(bpchfile=bpchfile, 
                tinfo_file=tinfo_file, 
                dinfo_file=dinfo_file, 
                ncfile=ncfile)
ds_tmp = xr.open_dataset(ncfile)
diff = ds_tmp['SpeciesConc_CO2Tag11'] - ds_tmp['SpeciesConc_CO2Tag13']
#diff[0,0,:,:].plot()
dr = (ds_tmp['SpeciesConc_CO2Tag5'][0,0,:,:] - 1e5)/1e3
dr.plot()
# Out:
# Could not find file /geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-bio-2018-07/ts_satellite.20180708.bpch
# --------------------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-7-2c47e33b204f> in <module>
#      13                 tinfo_file=tinfo_file,
#      14                 dinfo_file=dinfo_file,
# ---> 15                 ncfile=ncfile)
#      16 ds_tmp = xr.open_dataset(ncfile)
#      17 diff = ds_tmp['SpeciesConc_CO2Tag11'] - ds_tmp['SpeciesConc_CO2Tag13']
#
# /geos/u73/msadiq/GEOS-Chem/analysis/inversion/bpch2nc.py in bpch_2_netcdf(bpchfile, tinfo_file, dinfo_file, ncfile, interval)
#      28         ds = xb.open_bpchdataset(filename=bpchfile,
#      29                                  tracerinfo_file=tinfo_file,
# ---> 30                                  diaginfo_file=dinfo_file)
#      31     except FileNotFoundError:
#      32         print('Could not find file {}'.format(bpchfile))
#
# /geos/u73/msadiq/libs/miniconda/base/envs/geo/lib/python3.6/site-packages/xbpch/core.py in open_bpchdataset(filename, fields, categories, tracerinfo_file, diaginfo_file, endian, decode_cf, memmap, dask, return_store)
#      79         tracerinfo_file=tracerinfo_file,
#      80         diaginfo_file=diaginfo_file, endian=endian,
# ---> 81         use_mmap=memmap, dask_delayed=dask
#      82     )
#      83     ds = xr.Dataset.load_store(store)
#
# /geos/u73/msadiq/libs/miniconda/base/envs/geo/lib/python3.6/site-packages/xbpch/core.py in __init__(self, filename, fields, categories, fix_cf, mode, endian, diaginfo_file, tracerinfo_file, use_mmap, dask_delayed)
#     251
#     252         self.filename = filename
# --> 253         self.fsize = os.path.getsize(self.filename)
#     254         self.mode = mode
#     255         if not mode.startswith('r'):
#
# /geos/u73/msadiq/libs/miniconda/base/envs/geo/lib/python3.6/genericpath.py in getsize(filename)
#      48 def getsize(filename):
#      49     """Return the size of a file, reported by os.stat()."""
# ---> 50     return os.stat(filename).st_size
#      51
#      52
#
# FileNotFoundError: [Errno 2] No such file or directory: '/geos/u73/msadiq/GEOS-Chem/rundirs/ensemble_runs/CO2-bio-2018-07/ts_satellite.20180708.bpch'
